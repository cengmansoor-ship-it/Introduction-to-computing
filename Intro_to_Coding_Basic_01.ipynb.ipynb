# %% [markdown]
# ## Expressions

# %% [markdown]
# ###### Lets Start with some basic expressions

# %%
15

# %%
-2 + 5

# %%
-2 - 1

# %%
-2 - -1

# %%
4/2     # / Forward slash,  \ Backward slah {Skip character}

# %%
1/2

# %%
15 % 4

# %%
15 % 2

# %%
1 / 2.0

# %%
type(1)

# %%
type(2.0)

# %%
1/2.0 + 1/4.0

# %%
2.1 + 5.3

# %%
2 + 2 * 2  # Presedence

# %% [markdown]
# ##### See more about presedence here

# %% [markdown]
# #### https://docs.python.org/3/reference/expressions.html/operator-presedence

# %% [markdown]
# #### Coditional operator

# %%
3 < 4

# %%
3 == 4

# %%
3 == 3

# %%
3 = 3

# %%
3 > 4

# %%
3 >= 3

# %%
2 <= 1

# %% [markdown]
# # Other types of Expressions

# %% [markdown]
# #### String

# %%
'Abc'

# %%
"Abc"  # In python there is no deffrent between bouble and single qoutes

# %%
""" This is a multilines string,
It can span multiple lines. """

# %% [markdown]
# #### Upper Case

# %%
a = "Hello world"
print(a.upper())

# %% [markdown]
# #### Lower Case

# %%
a = "HELLO, WOLRD"
print(a.lower())

# %% [markdown]
# #### Remove Whitespace

# %%
a = " Hello, world "
print(a.strip()) # مخ او شاته سپېسونه له منځه وړي

# %% [markdown]
# #### Replace string

# %%
a = "Hello, world"
print(a.replace("H", "J"))

# %% [markdown]
# #### Split string

# %%
a = "Hello wolrd"
print(a.split("."))

# %%
"ab" + "cd"    # concatination

# %%
"a" * 5

# %% [markdown]
# #### Logical operators

# %%
True and True

# %%
True and False

# %%
False and True

# %%
False and False

# %%
True or True

# %%
True or False

# %%
False or True

# %%
False or False

# %%
True or False and False or False

# %%
(True or False) and (False or False)  # Overriding

# %% [markdown]
# ## Call Expressions

# %%
max(7, 9)

# %%
max(2+5, 9)

# %%
pow(100, 2)

# %% [markdown]
# ## Importing library Functions

# %%
import math # Importing mathematics library

# %%
math.sqrt(256) # This is a kind of call expression

# %%
from math import sqrt # import just the sqrt function from mathematics library # call direction

# %%
sqrt(256)

# %%
help(math)  # documentation of this library

# %%
help(math.sqrt) # documentation of this specific sqrt

# %% [markdown]
# ## Naming the Numbers

# %%
x = 24

# %%
x = 3 # د رياضي متحول د پروګرامینګ ثابت دي 
# په رياضي کي متحول يو واري تغير کیږي خو په پروګرامينګ هر ګړي تغير کېداي سي
# رياضي ثابت: يو ځلي يې هم نسې تغير کولاي
# پروګرامينک ثابت: يو ځلې يې تغير کولای سې بيا يې نسې تغير کولای

# %%
x * 2

# %%
y = x * 2

# %%
y = x * 2.0

# %%
y = 'a' * 2

# %%
y

# %%
type(y)

# %%
y * 3

# %% [markdown]
# ## In C Syntax
# #### int y;
# ###### دلته ډيټاټايپ هم يو ځلي ورکولای سې
# #### y = x * 2;

# %% [markdown]
# ## Importing variable from libraries

# %%
from math import pi

# %%
pi

# %%
pi * 4 * 4 # area of a cicle with radius 4cm

# %%
a = 4

# %%
pi * pow(4, 2) # ذلته د ار په شکل کي معلوميږي

# %%
radius = 4

# %%
pi * pow(radius, 4) # More readable and more clear

# %%
a = 4
b = 2

# %%
pi * pow(a, b) # This is only readable

# %% [markdown]
# ## What happens when you try to use a variable that is not known

# %%
v # Undefined variable

# %%
4/0 # Zero_Division_Error

# %% [markdown]
# ## Naming Functions

# %%
sqrt(25) # Call expression

# %%
sqrt # What is sqrt?

# %%
f = sqrt

# %%
f(25)

# %%
sqrt(25)

# %% [markdown]
# ##### $Visualization python         [Python totur]$
# ###### We should know about all the things in visualization

# %% [markdown]
# # Side Effects

# %% [markdown]
# ###### د انپوټ چي پر اوټ پوټ کوم حقوق دي اوټ پوټ دهغه علاوه نور څه هم درته راوړي

# %%
print f(25)

# %%
f(25)

# %%
"a"

# %%
print("a")

# %%
print("value of f(25) is: ", f(25))

# %%
s = """  This is a multilines string,         It can span multiple lines. """

# %%
s # ته انټرپرېټر ته وايي چي ددې قيمت څو دي؟ چي زه کار پر وکړم

# %%
print(s) #یوازي يې پر سکرين راته پرینټ کړه

# %% [markdown]
# ##### python tutor
# ###### د سايډ افکټ او اس ویليو ترمنځ بايد فرق واضح سي

# %% [markdown]
# # Defining new functions

# %% [markdown]
# ### We can define new functions using the def commmand.

# %%
def square(x):
    return x * x   # Notice the indentation and standardize by [1tab, 4spaces]

# %% [markdown]
# #### And we call this function as before

# %%
square(5)

# %%
v = square(5)

# %%
v

# %%
def square(x):
    print x * x # We can use the return value nother then print we can not as a variable.

# %%
v = square(5)

# %%
v

# %%
type(v)

# %%
v

# %%
v = square(5.0)

# %%
type(v) # type of a function is regarding to the type of arguments

# %% [markdown]
# ### Aside: in C, functions are defines as followning:

# %% [markdown]
# ##### float square(float x){
#     return x * x;
# }

# %% [markdown]
# ## Obviously, we can call function within other functions.

# %%
def sum_squares(x, y)
    return square(x) + square(y)

# %%
result = sum_squares(3, 4)

# %%
result

# %% [markdown]
# #### There is another important point here that we highlight through our slide
# ##### Static semantic error

# %%
sum_squares('a', 2) # String does not multiply with string

# %% [markdown]
# ## Defualt values

# %% [markdown]
# #### We can give meaningful defualt values to arguments.
# #### Let's see an example from our favorite square root function.

# %%
def sqrt(num, guess = 1):
    print("Find the square root of ", num, "Starting with guess: ", guess)

# %%
sqrt(36) # But we don't need to specify the 1

# %%
sqrt(36, 5.5)

# %% [markdown]
# ## Scope

# %% [markdown]
# #### Where can you see the variables?

# %%
def f(x):
    y = 1
    x = x + y
    print('x = ' ,x)
    print('p = ' ,p) # global variables
    return x

p = 20  # local variables
x = 3
y = 2
z = f(x)

print('z = ',z)
print('x = ',x)
print('y = ',y)

# %%
y = 25

def f(x):
    print('y = ',y)
    x = 25 + 9
    
    y = 1 # variables are global unless assigned to inside the function 
    # UnboundLocalError
x = 2
f(x)

# %%
y = 25

def f(x):
    y = 1 # variables are global unless assigned to inside the function
    print('y = ',y)
    x = 25 + 9
    
     

x = 2
f(x)

# %% [markdown]
# ## Designing Functions

# %% [markdown]
# #### It's important to design your functions thoughtfully. Some important point points to note:
# ##### ---> That will be in slides

# %%
def pressure(v, t, n):
    """Compute the pressure in pascals of an ideal gas.

    applies the ideal gas law 

    v -- volume of gas, in cubic meters 
    t -- absolute temperature in degrees kelvin
    n -- particles of gas 
    """ # Documentation string
    
    k = 1.38e-23 # Boltzmann's constant
    return n * k * t / v

# %%
help(pressure)

# %% [markdown]
# ## Compound Statements

# %%
def percent_difference(x, y):
    difference = abs(x-y)
    return 100 * difference / x

result = percent_difference(40, 50)

# %%
result

# %%
def absolute_value(x):
    """ Compute abs(x). """
    if x > 0:
        return x

    elif x == 0:
        return 0

    else:
        return -x

# %%
absolute_value(5)

# %%
absolute_value(0)

# %%
absolute_value(-5)

# %% [markdown]
# ## Iteration, Repetition, Loop

# %% [markdown]
# ##### Sometimes, you want to do things more than once.

# %%
print("put sugar in.")
print("put milk in.")
print("put tea leaves in.")

# %%
for ingredient in 'sugar', 'milk', 'tea leaves': # ګټه يې داده چي مخکي مو مکمله جمله ليکل اوس فقط اټم وراضافه کوو
    print('put', ingredient, 'in')

# %% [markdown]
# #### Back to the tutor

# %%
for i in 2, 3, 4, 5, 6, 7, 8, 9:
    print(i)

print('Done')

# %%
for i in range(2, 10):
    print(i)

print('Done')

# %%
for i in range(10):    # This is the end point boundry only
    print(i)

print('Done')

# %% [markdown]
# #### Sometimes, we didn't know how many time run the loop...

# %% [markdown]
# #### ...but we do know when to stop. this is called the "While loop".

# %% [markdown]
# ##### For example: we want to print all multiples of 0.13 from 0 to 1. But we don't know how many of those there are.

# %%
n = 0.13

while n < 13:
    print(n)
    n = n + 0.13

# print(n)
print('Done')

# %%
n = 0.13

while n < 1:
    n = n + 0.13
    print(n)  # This is a kind of semantic error


# print(n)
print('Done')

# %%
# We can also count how many there were by saving the count
n = 0.13
i = 0

while n < 1:
    i = i + 1 # دې په دا خاطر اجراء کيږي د بوډي په داخل کي دي
    print(n)
    n = n + 0.13

print(i)
print('Done')

# %%
for i in range(2, 10):           # loop over a few numbers
     # اول خپل فکر انګليسي عبارت ته واړوه
     # بيا يې د عبارت څخه کوډ ته واړوه
     # بيا په کوډ کي کومي فارمولې ته چي ضرورت وي هغه مفهوم پکښي استعمال کړه
    if even_wi:
        print(i)

print('Done')

# %% [markdown]
# ##### For even numbers

# %%
for i in range(2, 10):           # loop over a few numbers
    
    if i%2==0:
        print(i)

print('Done')

# %% [markdown]
# ##### For odd numbers

# %% [markdown]
# ###### Three ways

# %%
# First way
for i in range(2, 10):           # loop over a few numbers
    
    if i%2==1:
        print(i)

print('Done')

# %%
# Second way
for i in range(2, 10):           # loop over a few numbers
    
    if not i%2==0:
        print(i)

print('Done')

# %%
# Third way
for i in range(2, 10):           # loop over a few numbers
    
    if i%2 != 0:
        print(i)

print('Done')

# %% [markdown]
# ##### continue keyword

# %%
for i in range(2, 10):           # loop over a few numbers
    
    if not i%2==0:
        
        continue
        # دا کيورډ هغه اخستې ویليو ايسته(سکيپ) کوي
    
    print(i)

print('Done')

# %% [markdown]
# ##### break keyword

# %%
for i in range(2, 10):           # loop over a few numbers
    
    if i % 5 == 0:

        break
    
    print(i)

print('Done')

# %% [markdown]
# ![1.PNG](attachment:3c54f3a0-cd9a-487e-99ed-b3fb78601263.PNG)

# %% [markdown]
# ![2.PNG](attachment:c994e8a7-5e3b-4eee-bb50-6a306f286bfa.PNG)

# %%
fact = 1   # typically, the iteration variable is called i or j

for i in range(1, 5):
    fact = fact * i


print(fact)

# %% [markdown]
# ##### The bellow is infinite loop

# %% [markdown]
# ##### because of modify operator

# %%
fact = 1   

#i = 1
#while i <= 4:
#   fact = fact * i


print(fact)

# %%
fact = 1   

i = 1
while i <= 120:
    fact = fact * i
    i = i + 1

print(fact)

# سي د ۱۲۰ فکټوريل نسي ورکولای

# %% [markdown]
# ![3.PNG](attachment:6d3de467-ac98-4ae0-a2e1-fe5cc2db5222.PNG)

# %% [markdown]
# ![4.PNG](attachment:7b6bf60a-345d-40dd-b73a-d7f230550efc.PNG)

# %% [markdown]
# ##### Golden spiral

# %% [markdown]
# ![5.PNG](attachment:1a40ee04-f8d5-4b9b-b49f-32114f31a3ea.PNG)

# %% [markdown]
# ###### Spiral is use in photography for FOCUSE

# %% [markdown]
# ![6.PNG](attachment:7c7f9e78-9625-43f8-9921-5f67442d7c3e.PNG)

# %%
def fib(n):
    if n <= 1:
        return n

    else:
        return fib(n-1) + fib(n-2)

# %%
fib(1)  # Let's also try 2, 3, 5, 7, 10

# %% [markdown]
# ##### % time ... د اګزيکيوشن وخت درښه يې

# %%
# %time fib(35)  # this will take a bit of time

# %% [markdown]
# ##### This is slow
# ##### So how can we fix this problem in this course

# %%
def fib2():
    if n<= 1: return n

    a, b = 0, 1

    for i in range(1, n+1):
        n = a + b
        a = b
        b = n

    return a

# %%
0, 1
^  ^
a, b

# %%
fib2(4)

# %%
# %time fib2(35)
